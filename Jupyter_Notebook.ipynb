# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# ## HEADER OF MY PROJECT

# %% [markdown]
# Enterance of my project

# %% [markdown]
# Data Science Languages:
# 1.Python
# 2.R Studio
# 3.java
# 4.julia
# 5.C/C++

# %% [markdown]
# Data Science libraries:
# 1.Numpy
# 2.Pandas
# 3.Matplotlib
# 4.Seaborn
# 5.plotly
# 6.Scikit-learn
# 7.keras

# %%
a=1
b=1.3
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>

# %%
a=13
b=23
c=7

print(a+b+c)
print(b-c)
print(b/c)
print(a*c)
# Out:
# 43
# 16
# 3.2857142857142856
# 91

# %% [markdown]
# My targets :
# 1.İmprove my data science skills
# 2.become a data scientist

# %% [markdown]
# Author:
#     Kaan ŞAHİN
